# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('/content/car_prices.csv')
df
# Out:
#     Mileage  Age(yrs)  Sell Price($)
# 0     69000         6          18000
# 1     35000         3          34000
# 2     57000         5          26100
# 3     22500         2          40000
# 4     46000         5          31500
# 5     59000         5          26750
# 6     52000         5          32000
# 7     52000         6          19300
# 8     59000         5          12000
# 9     52000         5          22000
# 10    91000         8          12000
# 11    61000         6          18700
# 12    83000         7          19700
# 13    79000         6          19500
# 14    59000         5          26000
# 15    85000         4          27500
# 16    58740         4          27500
# 17    25400         3          35000
# 18    69000         5          35500
# 19    69000         5          19700
# 20    87600         5          12800
# 21    52000         5          28200

# %%
#here milage and age are independent variables where as price dependent variable

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Millege vs Price

# %%
plt.scatter(df['Mileage'],df['Sell Price($)'])

# %% [markdown]
# CarAge vs Price

# %%
plt.scatter(df['Age(yrs)'],df['Sell Price($)'])

# %%
from os import X_OK
X=df[['Mileage','Age(yrs)']]
Y=df['Sell Price($)']
X
# Out:
#     Mileage  Age(yrs)
# 0     69000         6
# 1     35000         3
# 2     57000         5
# 3     22500         2
# 4     46000         5
# 5     59000         5
# 6     52000         5
# 7     52000         6
# 8     59000         5
# 9     52000         5
# 10    91000         8
# 11    61000         6
# 12    83000         7
# 13    79000         6
# 14    59000         5
# 15    85000         4
# 16    58740         4
# 17    25400         3
# 18    69000         5
# 19    69000         5
# 20    87600         5
# 21    52000         5

# %%
Y
# Out:
# 0     18000
# 1     34000
# 2     26100
# 3     40000
# 4     31500
# 5     26750
# 6     32000
# 7     19300
# 8     12000
# 9     22000
# 10    12000
# 11    18700
# 12    19700
# 13    19500
# 14    26000
# 15    27500
# 16    27500
# 17    35000
# 18    35500
# 19    19700
# 20    12800
# 21    28200
# Name: Sell Price($), dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=10)

# %%
len(X)
# Out:
# 22

# %%
len(X_train) #80 % of x=x_train
# Out:
# 17

# %%
len(X_test)#20%
# Out:
# 5

# %%
X_train
# Out:
#     Mileage  Age(yrs)
# 17    25400         3
# 7     52000         6
# 6     52000         5
# 9     52000         5
# 2     57000         5
# 0     69000         6
# 1     35000         3
# 10    91000         8
# 11    61000         6
# 4     46000         5
# 3     22500         2
# 13    79000         6
# 16    58740         4
# 5     59000         5
# 8     59000         5
# 15    85000         4
# 14    59000         5

# %%
X_test
# Out:
#     Mileage  Age(yrs)
# 21    52000         5
# 20    87600         5
# 12    83000         7
# 19    69000         5
# 18    69000         5

# %%
from sklearn.linear_model import LinearRegression
clf=LinearRegression()
clf
# Out:
# LinearRegression()

# %%
clf.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
clf.predict(X_test)
# Out:
# array([25170.12525897, 25170.12525897, 25531.94656819, 22388.08889863,
#        24016.28479014])

# %%
Y_test
# Out:
# 14    26000
# 5     26750
# 2     26100
# 11    18700
# 7     19300
# Name: Sell Price($), dtype: int64

# %%
clf.score(X_test,Y_test) #accuracy is 38% beacause nature of my dataset
# Out:
# 0.3867235548796285
